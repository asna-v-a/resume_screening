# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/asnav/Documents/MachineLearningProjects/resume_sreening/data/dataset.csv")
df.head()
# Out:
#           ID             Name                        Role  \
# 0  jasojo159      Jason Jones       E-commerce Specialist
# 1   annma759     Ann Marshall              Game Developer
# 2  patrmc729  Patrick Mcclain  Human Resources Specialist
# 3  patrgr422    Patricia Gray       E-commerce Specialist
# 4  amangr696     Amanda Gross       E-commerce Specialist
#
#                                           Transcript  \
# 0  Interviewer: Good morning, Jason. It's great t...
# 1  Interview Scene\n\nA conference room with a ta...
# 2  Interview Setting: A conference room in a medi...
# 3  Here's a simulated professional interview for ...
# 4  Here's the simulated interview:\n\nInterviewer...
#
#                                               Resume decision  \
# 0  Here's a professional resume for Jason Jones:\...   reject
# 1  Here's a professional resume for Ann Marshall:...   select
# 2  Here's a professional resume for Patrick Mccla...   reject
# ...

# %%
df.tail()
# Out:
#               ID            Name             Role  \
# 10169  uppaup496    Diana Miller  Product Manager
# 10170  uppaup497    Grace Taylor      UI Engineer
# 10171  uppaup498      Hank Brown      UI Engineer
# 10172  uppaup499    Diana Wilson    Data Engineer
# 10173  uppaup500  Charlie Miller  Product Manager
#
#                                               Transcript  \
# 10169  Here's a simulated interview for a Product Man...
# 10170  **Interviewer:** Hi Grace, thank you for comin...
# 10171  Here's a simulated interview for a UI Engineer...
# 10172  Here's a simulated interview for a Data Engine...
# 10173  Here's a simulated interview for a Product Man...
#
#                                                   Resume decision  \
# 10169  Here's a sample resume for Diana Miller:\n\n**...   reject
# 10170  Here's a sample resume for Grace Taylor:\n\n**...   reject
# 10171  Here's a sample resume for Hank Brown:\n\n**Ha...   select
# ...

# %%
df.shape
# Out:
# (10174, 8)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Role', 'Transcript', 'Resume', 'decision',
#        'Reason_for_decision', 'Job_Description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10174 entries, 0 to 10173
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10174 non-null  object
#  1   Name                 10174 non-null  object
#  2   Role                 10174 non-null  object
#  3   Transcript           10174 non-null  object
#  4   Resume               10174 non-null  object
#  5   decision             10174 non-null  object
#  6   Reason_for_decision  10174 non-null  object
#  7   Job_Description      10174 non-null  object
# dtypes: object(8)
# memory usage: 636.0+ KB

# %%
df.describe()
# Out:
#                ID   Name            Role  \
# count       10174  10174           10174
# unique      10171   8677              45
# top     michmo483  Lucas  Data Scientist
# freq            2     21             538
#
#                                                Transcript  \
# count                                               10174
# unique                                              10174
# top     Here's a simulated interview for a Product Man...
# freq                                                    1
#
#                                                    Resume decision  \
# count                                               10174    10174
# unique                                              10174        2
# top     Here's a sample resume for Charlie Miller, a P...   reject
# freq                                                    1     5114
#
#                                       Reason_for_decision  \
# count                                               10174
# ...

# %%
df.isna().sum()
# Out:
# ID                     0
# Name                   0
# Role                   0
# Transcript             0
# Resume                 0
# decision               0
# Reason_for_decision    0
# Job_Description        0
# dtype: int64
